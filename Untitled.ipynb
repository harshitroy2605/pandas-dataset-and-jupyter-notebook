# %% [markdown]
# # pandas with machine learning

# %%
import numpy as np
import pandas as pd
df = pd.read_csv('cars.csv',delimiter=';')
df.head(20)
# Out:
#                                  Car     MPG Cylinders Displacement  \
# 0                             STRING  DOUBLE       INT       DOUBLE
# 1          Chevrolet Chevelle Malibu    18.0         8        307.0
# 2                  Buick Skylark 320    15.0         8        350.0
# 3                 Plymouth Satellite    18.0         8        318.0
# 4                      AMC Rebel SST    16.0         8        304.0
# 5                        Ford Torino    17.0         8        302.0
# 6                   Ford Galaxie 500    15.0         8        429.0
# 7                   Chevrolet Impala    14.0         8        454.0
# 8                  Plymouth Fury iii    14.0         8        440.0
# 9                   Pontiac Catalina    14.0         8        455.0
# 10                AMC Ambassador DPL    15.0         8        390.0
# 11              Citroen DS-21 Pallas       0         4        133.0
# 12  Chevrolet Chevelle Concours (sw)       0         8        350.0
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.tail(10)
# Out:
#                             Car   MPG Cylinders Displacement Horsepower  \
# 397  Chrysler Lebaron Medallion  26.0         4        156.0      92.00
# 398              Ford Grenada l  22.0         6        232.0      112.0
# 399            Toyota Celica GT  32.0         4        144.0      96.00
# 400           Dodge Charger 2.2  36.0         4        135.0      84.00
# 401            Chevrolet Camaro  27.0         4        151.0      90.00
# 402             Ford Mustang GL  27.0         4        140.0      86.00
# 403           Volkswagen Pickup  44.0         4        97.00      52.00
# 404               Dodge Rampage  32.0         4        135.0      84.00
# 405                 Ford Ranger  28.0         4        120.0      79.00
# 406                  Chevy S-10  31.0         4        119.0      82.00
#
#     Weight Acceleration Model  Origin
# 397  2585.         14.5    82      US
# 398   2835         14.7    82      US
# 399  2665.         13.9    82   Japan
# ...

# %%
df.shape
# Out:
# (407, 9)

# %%
df.size
# Out:
# 3663

# %%
df.columns
# Out:
# Index(['Car', 'MPG', 'Cylinders', 'Displacement', 'Horsepower', 'Weight',
#        'Acceleration', 'Model', 'Origin'],
#       dtype='object')

# %%
df[['Car','Cylinders']].head(10)
# Out:
#                          Car Cylinders
# 0                     STRING       INT
# 1  Chevrolet Chevelle Malibu         8
# 2          Buick Skylark 320         8
# 3         Plymouth Satellite         8
# 4              AMC Rebel SST         8
# 5                Ford Torino         8
# 6           Ford Galaxie 500         8
# 7           Chevrolet Impala         8
# 8          Plymouth Fury iii         8
# 9           Pontiac Catalina         8

# %%
df.sort_values(['Cylinders']).head()
# Out:
#                      Car   MPG Cylinders Displacement Horsepower Weight  \
# 251           Mazda RX-4  21.5         3        80.00      110.0  2720.
# 79       Mazda RX2 Coupe  19.0         3        70.00      97.00  2330.
# 119            Mazda RX3  18.0         3        70.00      90.00  2124.
# 342        Mazda RX-7 GS  23.7         3        70.00      100.0  2420.
# 263  Ford Fairmont (man)  25.1         4        140.0      88.00  2720.
#
#     Acceleration Model Origin
# 251         13.5    77  Japan
# 79          13.5    72  Japan
# 119         13.5    73  Japan
# 342         12.5    80  Japan
# 263         15.4    78     US

# %%
degree=df['Cylinders'].value_counts()
degree
# Out:
# 4      207
# 8      108
# 6       84
# 3        4
# 5        3
# INT      1
# Name: Cylinders, dtype: int64

# %%
# %matplotlib inline
degree.plot(kind='bar')

# %%
df.iloc[2:5,1:4]
# Out:
#     MPG Cylinders Displacement
# 2  15.0         8        350.0
# 3  18.0         8        318.0
# 4  16.0         8        304.0

# %%
df=df.set_index('Car')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\python36\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Car'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-bbe379cbbd41> in <module>
# ----> 1 df=df.set_index('Car')
#       2 df.head()
#
# ...

# %%
df.head()
# Out:
#                               MPG Cylinders Displacement Horsepower  Weight  \
# Car
# STRING                     DOUBLE       INT       DOUBLE     DOUBLE  DOUBLE
# Chevrolet Chevelle Malibu    18.0         8        307.0      130.0   3504.
# Buick Skylark 320            15.0         8        350.0      165.0   3693.
# Plymouth Satellite           18.0         8        318.0      150.0   3436.
# AMC Rebel SST                16.0         8        304.0      150.0   3433.
#
#                           Acceleration Model Origin
# Car
# STRING                          DOUBLE   INT    CAT
# Chevrolet Chevelle Malibu         12.0    70     US
# Buick Skylark 320                 11.5    70     US
# Plymouth Satellite                11.0    70     US
# AMC Rebel SST                     12.0    70     US
